# %% [markdown]
# <a href="https://colab.research.google.com/github/fbrandao2k/AI-ComputerVision/blob/main/YOLO_v4_Detec%C3%A7%C3%A3o_de_objetos_em_v%C3%ADdeos_com_Darknet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detectando objetos em videos com YOLOv4

# %% [markdown]
# ## Etapa 1 - Download do Darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# %cd darknet
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet

# %%
ls
# Out:
# 3rdparty/       darknet*                Dockerfile.cpu          Makefile        scripts/
# backup/         DarknetConfig.cmake.in  Dockerfile.gpu          net_cam_v3.sh*  src/
# build/          darknet_images.py       image_yolov3.sh*        net_cam_v4.sh*  vcpkg.json
# build.ps1*      darknet.py              image_yolov4.sh*        obj/            vcpkg.json.opencv23
# cfg/            darknet_video.py        include/                package.xml     video_yolov3.sh*
# cmake/          data/                   json_mjpeg_streams.sh*  README.md       video_yolov4.sh*
# CMakeLists.txt  docker-compose.yml      LICENSE                 results/

# %% [markdown]
# ## Etapa 2 - Compilando a biblioteca

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# /device:GPU:0

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ...

# %% [markdown]
# ## Etapa 3 - Carregando os pesos do modelo pré-treinado

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
import zipfile
path = "/content/gdrive/MyDrive/ColabNotebooks/modelo_YOLOv4.zip"
zip_object = zipfile.ZipFile(file=path, mode="r")
zip_object.extractall("./")
zip_object.close()

# %% [markdown]
# ## Etapa 4 - Carregando o vídeo

# %% [markdown]
# ### 4.1 - De uma url

# %%
# !wget https://github.com/gabevr/yolo/raw/master/videos/video_teste02.mp4
# Out:
# --2024-07-17 19:48:57--  https://github.com/gabevr/yolo/raw/master/videos/video_teste02.mp4
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gabevr/yolo/master/videos/video_teste02.mp4 [following]
# --2024-07-17 19:48:57--  https://raw.githubusercontent.com/gabevr/yolo/master/videos/video_teste02.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7266878 (6.9M) [application/octet-stream]
# Saving to: ‘video_teste02.mp4’
#
# video_teste02.mp4   100%[===================>]   6.93M  --.-KB/s    in 0.04s
#
# ...

# %% [markdown]
# ### 4.2 - Do Google Drive

# %%
#!cp /content/gdrive/My\ Drive/Cursos\ -\ recursos/YOLO/videos/video_teste02.mp4 ./
# !cp /content/gdrive/MyDrive/Database/0-Estudos/USP_PhD/14-AI/YOLO/Module1/videos/video_teste02.mp4 ./

# %%
ls

# %% [markdown]
# ## Etapa 5 - Realizando a detecção em vídeo

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show video_teste02.mp4 -i 0 -out_filename resultado.avi
# Out:
# Streaming output truncated to the last 5000 lines.
# traffic light: 38%
# traffic light: 27%
# truck: 53%
# car: 61%
# truck: 31%
# car: 100%
# car: 100%
# car: 96%
# car: 94%
# car: 93%
# car: 93%
# car: 92%
# car: 85%
# car: 44%
#
# FPS:21.2 	 AVG_FPS:20.4
#
#  cvWriteFrame
# Objects:
#
# traffic light: 97%
# traffic light: 92%
# traffic light: 56%
# traffic light: 32%
# truck: 61%
# car: 53%
# truck: 31%
# car: 88%
# car: 100%
# car: 100%
# car: 97%
# car: 97%
# car: 94%
# car: 94%
# car: 86%
# car: 50%
# car: 28%
#
# FPS:21.0 	 AVG_FPS:20.4
#
#  cvWriteFrame
# Objects:
#
# traffic light: 97%
# traffic light: 93%
# traffic light: 64%
# traffic light: 44%
# truck: 58%
# car: 52%
# car: 100%
# car: 100%
# car: 98%
# car: 97%
# car: 97%
# car: 96%
# car: 95%
# car: 91%
# car: 39%
#
# FPS:20.9 	 AVG_FPS:20.4
#
#  cvWriteFrame
# Objects:
#
# traffic light: 97%
# traffic light: 93%
# traffic light: 64%
# traffic light: 44%
# truck: 58%
# car: 51%
# car: 100%
# car: 100%
# car: 98%
# ...

# %%
# !du -h resultado.avi
# Out:
# 32M	resultado.avi

# %% [markdown]
# ## Etapa 6 - Visualizando o resultado

# %%
# !cp ./resultado.avi /content/gdrive/My\ Drive/Cursos\ -\ recursos/YOLO/videos/resultado1.avi
# Out:
# cp: cannot create regular file '/content/gdrive/My Drive/Cursos - recursos/YOLO/videos/resultado1.avi': No such file or directory

# %% [markdown]
# ## Especificando um threshold

# %%
# !wget https://github.com/gabevr/yolo/raw/master/videos/video_rua01.mp4

# %%
# !cp /content/gdrive/My\ Drive/Cursos\ -\ recursos/YOLO/videos/video_rua01.mp4 ./

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show video_rua01.mp4 -out_filename resultado02.avi -thresh 0.3

# %%
# !cp ./resultado02.avi /content/gdrive/My\ Drive/Cursos\ -\ recursos/YOLO/videos/resultado2.avi
